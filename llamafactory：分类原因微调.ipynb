# %% [markdown]
# ## 引言
# [前文](https://golfxiao.blog.csdn.net/article/details/141440847)训练时都做了一定的编码工作，其实有一些框架可以支持我们零代码微调，[LLama-Factory](https://llamafactory.readthedocs.io/zh-cn/latest/)就是其中一个。这是一个专门针对大语言模型的微调和训练平台，有如下特性：
# - 支持常见的模型种类：LLaMA、LLaVA、Mistral、Mixtral-MoE、Qwen、Yi、Gemma、Baichuan、ChatGLM、Phi 等等。
# - 支持单GPU和多GPU训练。
# - 支持全参微调、Lora微调、QLora微调。
# ……
# 还有很多优秀的特性，详细参考：[https://llamafactory.readthedocs.io/zh-cn/latest/](https://llamafactory.readthedocs.io/zh-cn/latest/)
#
# 本文会尝试用LLamaFactory进行一次多GPU训练。
#
# ## 参数配置
# LLamaFactory的训练参数采用yaml文件保存，在安装目录下的`examples`子目录下有各种微调方法的示例配置，可以直接拷贝一份进行修改。
#
# ![在这里插入图片描述](https://i-blog.csdnimg.cn/direct/95c191a523e840fc969c0d014c82047e.png)
#
# 查看配置文件

# %%
# !cat /data2/anti_fraud/train/sft-0910/qwen2_lora_sft.yaml
# Out:
# ### model
# model_name_or_path: /data2/anti_fraud/models/modelscope/hub/Qwen/Qwen2-1___5B-Instruct
# # resume_from_checkpoint: /data2/anti_fraud/models/Qwen2-1___5B-Instruct_ft_0826/checkpoint-1200
#
# ### method
# stage: sft
# do_train: true
# finetuning_type: lora
# lora_target: q_proj,k_proj,v_proj,o_proj,gate_proj,up_proj,down_proj
# lora_rank: 16
# lora_alpha: 32
# lora_dropout: 0.2
#
#
# ### dataset
# dataset_dir: /data2/anti_fraud/dataset/
# dataset: anti_fraud_0902
# template: qwen
# cutoff_len: 1024
# max_samples: 200000
# overwrite_cache: true
# preprocessing_num_workers: 16
#
# ### output
# output_dir: /data2/anti_fraud/models/Qwen2-1___5B-Instruct_ft_0910-3
# logging_steps: 10
# save_steps: 500
# plot_loss: true
# overwrite_output_dir: true
#
# ### train
# per_device_train_batch_size: 8
# gradient_accumulation_steps: 1
# gradient_checkpointing: true
# learning_rate: 1.0e-4
# num_train_epochs: 10.0
# lr_scheduler_type: cosine
# warmup_ratio: 0.05
# bf16: true
# ddp_timeout: 180000000
#
# ### eval
# val_size: 0.1
# per_device_eval_batch_size: 8
# eval_strategy: steps
# eval_steps: 100

# %% [markdown]
# ## 训练-1：低学习率
#
# 设置环境变量CUDA_VISIBLE_DEVICES声明训练过程中允许使用4张显卡，显卡编号分别为1、2、3、4。
#
# 使用	`llamafactory-cli`命令启动训练。

# %%
import os 

os.environ["CUDA_VISIBLE_DEVICES"] = "1,2,3,5"

# %%
# !llamafactory-cli train /data2/anti_fraud/train/sft-0910/qwen2_lora_sft.yaml
# Out:
# [2024-09-10 22:43:56,919] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
#  [WARNING]  async_io requires the dev libaio .so object and headers but these were not found.
#  [WARNING]  async_io: please install the libaio-dev package with apt
#  [WARNING]  If libaio is already installed (perhaps from source), try setting the CFLAGS and LDFLAGS environment variables to where it can be found.
#  [WARNING]  Please specify the CUTLASS repo directory as environment variable $CUTLASS_PATH
#  [WARNING]  sparse_attn requires a torch version >= 1.5 and < 2.0 but detected 2.4
#  [WARNING]  using untested triton version (3.0.0), only 1.0.0 is known to be compatible
# /data2/anaconda3/envs/python3_10/lib/python3.10/site-packages/deepspeed/runtime/zero/linear.py:49: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   def forward(ctx, input, weight, bias=None):
# /data2/anaconda3/envs/python3_10/lib/python3.10/site-packages/deepspeed/runtime/zero/linear.py:67: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, grad_output):
# WARNING 09-10 22:43:58 cuda.py:22] You are using a deprecated `pynvml` package. Please install `nvidia-ml-py` instead. See https://pypi.org/project/pynvml for more information.
# 09/10/2024 22:44:04 - INFO - llamafactory.cli - Initializing distributed tasks at: 127.0.0.1:21321
# W0910 22:44:05.753000 140124487410624 torch/distributed/run.py:779]
# W0910 22:44:05.753000 140124487410624 torch/distributed/run.py:779] *****************************************
# W0910 22:44:05.753000 140124487410624 torch/distributed/run.py:779] Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# W0910 22:44:05.753000 140124487410624 torch/distributed/run.py:779] *****************************************
# [2024-09-10 22:44:10,233] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-09-10 22:44:10,251] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-09-10 22:44:10,256] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-09-10 22:44:10,288] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
#  [WARNING]  async_io requires the dev libaio .so object and headers but these were not found.
#  [WARNING]  async_io requires the dev libaio .so object and headers but these were not found.
#  [WARNING]  async_io requires the dev libaio .so object and headers but these were not found.
#  [WARNING]  async_io requires the dev libaio .so object and headers but these were not found.
#  [WARNING]  async_io: please install the libaio-dev package with apt
#  [WARNING]  If libaio is already installed (perhaps from source), try setting the CFLAGS and LDFLAGS environment variables to where it can be found.
#  [WARNING]  Please specify the CUTLASS repo directory as environment variable $CUTLASS_PATH
#  [WARNING]  async_io: please install the libaio-dev package with apt
#  [WARNING]  If libaio is already installed (perhaps from source), try setting the CFLAGS and LDFLAGS environment variables to where it can be found.
#  [WARNING]  Please specify the CUTLASS repo directory as environment variable $CUTLASS_PATH
#  [WARNING]  async_io: please install the libaio-dev package with apt
#  [WARNING]  If libaio is already installed (perhaps from source), try setting the CFLAGS and LDFLAGS environment variables to where it can be found.
#  [WARNING]  Please specify the CUTLASS repo directory as environment variable $CUTLASS_PATH
#  [WARNING]  async_io: please install the libaio-dev package with apt
#  [WARNING]  If libaio is already installed (perhaps from source), try setting the CFLAGS and LDFLAGS environment variables to where it can be found.
#  [WARNING]  Please specify the CUTLASS repo directory as environment variable $CUTLASS_PATH
#  [WARNING]  sparse_attn requires a torch version >= 1.5 and < 2.0 but detected 2.4
#  [WARNING]  using untested triton version (3.0.0), only 1.0.0 is known to be compatible
#  [WARNING]  sparse_attn requires a torch version >= 1.5 and < 2.0 but detected 2.4
#  [WARNING]  using untested triton version (3.0.0), only 1.0.0 is known to be compatible
#  [WARNING]  sparse_attn requires a torch version >= 1.5 and < 2.0 but detected 2.4
#  [WARNING]  using untested triton version (3.0.0), only 1.0.0 is known to be compatible
# /data2/anaconda3/envs/python3_10/lib/python3.10/site-packages/deepspeed/runtime/zero/linear.py:49: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   def forward(ctx, input, weight, bias=None):
# /data2/anaconda3/envs/python3_10/lib/python3.10/site-packages/deepspeed/runtime/zero/linear.py:67: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, grad_output):
# /data2/anaconda3/envs/python3_10/lib/python3.10/site-packages/deepspeed/runtime/zero/linear.py:49: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   def forward(ctx, input, weight, bias=None):
# /data2/anaconda3/envs/python3_10/lib/python3.10/site-packages/deepspeed/runtime/zero/linear.py:67: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, grad_output):
# /data2/anaconda3/envs/python3_10/lib/python3.10/site-packages/deepspeed/runtime/zero/linear.py:49: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   def forward(ctx, input, weight, bias=None):
# /data2/anaconda3/envs/python3_10/lib/python3.10/site-packages/deepspeed/runtime/zero/linear.py:67: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, grad_output):
#  [WARNING]  sparse_attn requires a torch version >= 1.5 and < 2.0 but detected 2.4
#  [WARNING]  using untested triton version (3.0.0), only 1.0.0 is known to be compatible
# /data2/anaconda3/envs/python3_10/lib/python3.10/site-packages/deepspeed/runtime/zero/linear.py:49: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   def forward(ctx, input, weight, bias=None):
# /data2/anaconda3/envs/python3_10/lib/python3.10/site-packages/deepspeed/runtime/zero/linear.py:67: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, grad_output):
# WARNING 09-10 22:44:11 cuda.py:22] You are using a deprecated `pynvml` package. Please install `nvidia-ml-py` instead. See https://pypi.org/project/pynvml for more information.
# WARNING 09-10 22:44:11 cuda.py:22] You are using a deprecated `pynvml` package. Please install `nvidia-ml-py` instead. See https://pypi.org/project/pynvml for more information.
# WARNING 09-10 22:44:11 cuda.py:22] You are using a deprecated `pynvml` package. Please install `nvidia-ml-py` instead. See https://pypi.org/project/pynvml for more information.
# WARNING 09-10 22:44:11 cuda.py:22] You are using a deprecated `pynvml` package. Please install `nvidia-ml-py` instead. See https://pypi.org/project/pynvml for more information.
# 09/10/2024 22:44:17 - WARNING - llamafactory.hparams.parser - `ddp_find_unused_parameters` needs to be set as False for LoRA in DDP training.
# 09/10/2024 22:44:17 - INFO - llamafactory.hparams.parser - Process rank: 0, device: cuda:0, n_gpu: 1, distributed training: True, compute dtype: torch.bfloat16
# [INFO|tokenization_utils_base.py:2287] 2024-09-10 22:44:17,454 >> loading file vocab.json
# [INFO|tokenization_utils_base.py:2287] 2024-09-10 22:44:17,454 >> loading file merges.txt
# [INFO|tokenization_utils_base.py:2287] 2024-09-10 22:44:17,454 >> loading file tokenizer.json
# [INFO|tokenization_utils_base.py:2287] 2024-09-10 22:44:17,454 >> loading file added_tokens.json
# [INFO|tokenization_utils_base.py:2287] 2024-09-10 22:44:17,454 >> loading file special_tokens_map.json
# [INFO|tokenization_utils_base.py:2287] 2024-09-10 22:44:17,454 >> loading file tokenizer_config.json
# 09/10/2024 22:44:17 - WARNING - llamafactory.hparams.parser - `ddp_find_unused_parameters` needs to be set as False for LoRA in DDP training.
# 09/10/2024 22:44:17 - INFO - llamafactory.hparams.parser - Process rank: 1, device: cuda:1, n_gpu: 1, distributed training: True, compute dtype: torch.bfloat16
# [INFO|tokenization_utils_base.py:2533] 2024-09-10 22:44:17,734 >> Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# 09/10/2024 22:44:17 - INFO - llamafactory.data.template - Replace eos token: <|im_end|>
# 09/10/2024 22:44:17 - INFO - llamafactory.data.loader - Loading dataset train0902_alpaca.jsonl...
# 09/10/2024 22:44:17 - WARNING - llamafactory.hparams.parser - `ddp_find_unused_parameters` needs to be set as False for LoRA in DDP training.
# 09/10/2024 22:44:17 - INFO - llamafactory.hparams.parser - Process rank: 3, device: cuda:3, n_gpu: 1, distributed training: True, compute dtype: torch.bfloat16
# 09/10/2024 22:44:17 - WARNING - llamafactory.hparams.parser - `ddp_find_unused_parameters` needs to be set as False for LoRA in DDP training.
# 09/10/2024 22:44:17 - INFO - llamafactory.hparams.parser - Process rank: 2, device: cuda:2, n_gpu: 1, distributed training: True, compute dtype: torch.bfloat16
# 09/10/2024 22:44:17 - INFO - llamafactory.data.template - Replace eos token: <|im_end|>
# 09/10/2024 22:44:18 - INFO - llamafactory.data.template - Replace eos token: <|im_end|>
# 09/10/2024 22:44:18 - INFO - llamafactory.data.template - Replace eos token: <|im_end|>
# Converting format of dataset (num_proc=16): 100%|█| 24246/24246 [00:00<00:00, 75
# 09/10/2024 22:44:19 - INFO - llamafactory.data.loader - Loading dataset train0902_alpaca.jsonl...
# 09/10/2024 22:44:19 - INFO - llamafactory.data.loader - Loading dataset train0902_alpaca.jsonl...
# 09/10/2024 22:44:19 - INFO - llamafactory.data.loader - Loading dataset train0902_alpaca.jsonl...
# Running tokenizer on dataset (num_proc=16): 100%|█| 24246/24246 [00:03<00:00, 65
# training example:
# input_ids:
# [151644, 8948, 198, 2610, 525, 264, 10950, 17847, 13, 151645, 198, 151644, 872, 198, 56568, 101909, 101042, 106037, 102206, 9370, 101057, 3837, 103929, 88802, 20412, 101042, 100431, 105051, 43815, 116307, 99346, 106037, 9623, 761, 97957, 31252, 2641, 9231, 3837, 62244, 47606, 99346, 106037, 37945, 109363, 113872, 106037, 101070, 9370, 102588, 28946, 66187, 955, 97957, 643, 65474, 31252, 495, 9231, 3837, 62926, 107485, 103929, 101042, 102401, 61870, 31252, 495, 9231, 3837, 100161, 23031, 2236, 68805, 66017, 8997, 101965, 99958, 25, 10236, 36097, 54658, 99461, 104381, 101214, 27369, 37945, 87026, 104525, 112535, 3837, 107233, 104883, 54542, 3837, 103944, 101214, 104827, 100635, 99464, 8997, 99445, 100201, 25, 4891, 98, 121, 9370, 3837, 102570, 101900, 116211, 1773, 151645, 198, 151644, 77091, 198, 4913, 285, 761, 97957, 788, 895, 11, 330, 42289, 661, 643, 65474, 788, 7342, 330, 19895, 788, 1591, 92, 151645]
# inputs:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# 你是一个分析诈骗案例的专家，你的任务是分析下面对话内容是否存在经济诈骗(is_fraud:<bool>)，如果存在经济诈骗，请找出正在进行诈骗行为的发言者姓名(fraud_speaker:<str>)，并给出你的分析理由(reason:<str>)，最后以json格式输出。
# 梁豪: 系统已经收到您的信息，请您等待几分钟，我们会尽快处理，确保您的账户资金安全。
# 王伟: 好的，谢谢你们的帮助。<|im_end|>
# <|im_start|>assistant
# {"is_fraud": false, "fraud_speaker": "", "reason": ""}<|im_end|>
# label_ids:
# [-100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, 4913, 285, 761, 97957, 788, 895, 11, 330, 42289, 661, 643, 65474, 788, 7342, 330, 19895, 788, 1591, 92, 151645]
# labels:
# {"is_fraud": false, "fraud_speaker": "", "reason": ""}<|im_end|>
# [INFO|configuration_utils.py:731] 2024-09-10 22:44:23,798 >> loading configuration file /data2/anti_fraud/models/modelscope/hub/Qwen/Qwen2-1___5B-Instruct/config.json
# [INFO|configuration_utils.py:800] 2024-09-10 22:44:23,800 >> Model config Qwen2Config {
#   "_name_or_path": "/data2/anti_fraud/models/modelscope/hub/Qwen/Qwen2-1___5B-Instruct",
#   "architectures": [
#     "Qwen2ForCausalLM"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 151643,
#   "eos_token_id": 151645,
#   "hidden_act": "silu",
#   "hidden_size": 1536,
#   "initializer_range": 0.02,
#   "intermediate_size": 8960,
#   "max_position_embeddings": 32768,
#   "max_window_layers": 28,
#   "model_type": "qwen2",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 28,
#   "num_key_value_heads": 2,
#   "rms_norm_eps": 1e-06,
#   "rope_theta": 1000000.0,
#   "sliding_window": null,
#   "tie_word_embeddings": true,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.43.3",
#   "use_cache": true,
#   "use_sliding_window": false,
#   "vocab_size": 151936
# }
#
# [INFO|modeling_utils.py:3631] 2024-09-10 22:44:23,831 >> loading weights file /data2/anti_fraud/models/modelscope/hub/Qwen/Qwen2-1___5B-Instruct/model.safetensors
# [INFO|modeling_utils.py:1572] 2024-09-10 22:44:23,844 >> Instantiating Qwen2ForCausalLM model under default dtype torch.bfloat16.
# [INFO|configuration_utils.py:1038] 2024-09-10 22:44:23,846 >> Generate config GenerationConfig {
#   "bos_token_id": 151643,
#   "eos_token_id": 151645
# }
#
# 09/10/2024 22:45:57 - INFO - llamafactory.model.model_utils.checkpointing - Gradient checkpointing enabled.
# 09/10/2024 22:45:57 - INFO - llamafactory.model.model_utils.attention - Using torch SDPA for faster training and inference.
# 09/10/2024 22:45:57 - INFO - llamafactory.model.adapter - Upcasting trainable params to float32.
# 09/10/2024 22:45:57 - INFO - llamafactory.model.adapter - Fine-tuning method: LoRA
# 09/10/2024 22:45:57 - INFO - llamafactory.model.loader - trainable params: 18,464,768 || all params: 1,562,179,072 || trainable%: 1.1820
# 09/10/2024 22:46:04 - INFO - llamafactory.model.model_utils.checkpointing - Gradient checkpointing enabled.
# 09/10/2024 22:46:04 - INFO - llamafactory.model.model_utils.attention - Using torch SDPA for faster training and inference.
# 09/10/2024 22:46:04 - INFO - llamafactory.model.adapter - Upcasting trainable params to float32.
# 09/10/2024 22:46:04 - INFO - llamafactory.model.adapter - Fine-tuning method: LoRA
# [INFO|modeling_utils.py:4463] 2024-09-10 22:46:05,183 >> All model checkpoint weights were used when initializing Qwen2ForCausalLM.
#
# [INFO|modeling_utils.py:4471] 2024-09-10 22:46:05,183 >> All the weights of Qwen2ForCausalLM were initialized from the model checkpoint at /data2/anti_fraud/models/modelscope/hub/Qwen/Qwen2-1___5B-Instruct.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use Qwen2ForCausalLM for predictions without further training.
# [INFO|configuration_utils.py:991] 2024-09-10 22:46:05,186 >> loading configuration file /data2/anti_fraud/models/modelscope/hub/Qwen/Qwen2-1___5B-Instruct/generation_config.json
# [INFO|configuration_utils.py:1038] 2024-09-10 22:46:05,186 >> Generate config GenerationConfig {
#   "bos_token_id": 151643,
#   "do_sample": true,
#   "eos_token_id": [
#     151645,
#     151643
#   ],
#   "pad_token_id": 151643,
#   "repetition_penalty": 1.1,
#   "temperature": 0.7,
#   "top_k": 20,
#   "top_p": 0.8
# }
#
# 09/10/2024 22:46:05 - INFO - llamafactory.model.loader - trainable params: 18,464,768 || all params: 1,562,179,072 || trainable%: 1.1820
# 09/10/2024 22:46:05 - INFO - llamafactory.model.model_utils.checkpointing - Gradient checkpointing enabled.
# 09/10/2024 22:46:05 - INFO - llamafactory.model.model_utils.attention - Using torch SDPA for faster training and inference.
# 09/10/2024 22:46:05 - INFO - llamafactory.model.adapter - Upcasting trainable params to float32.
# 09/10/2024 22:46:05 - INFO - llamafactory.model.adapter - Fine-tuning method: LoRA
# 09/10/2024 22:46:05 - INFO - llamafactory.model.model_utils.checkpointing - Gradient checkpointing enabled.
# 09/10/2024 22:46:05 - INFO - llamafactory.model.model_utils.attention - Using torch SDPA for faster training and inference.
# 09/10/2024 22:46:05 - INFO - llamafactory.model.adapter - Upcasting trainable params to float32.
# 09/10/2024 22:46:05 - INFO - llamafactory.model.adapter - Fine-tuning method: LoRA
# 09/10/2024 22:46:05 - INFO - llamafactory.model.loader - trainable params: 18,464,768 || all params: 1,562,179,072 || trainable%: 1.1820
# 09/10/2024 22:46:05 - INFO - llamafactory.model.loader - trainable params: 18,464,768 || all params: 1,562,179,072 || trainable%: 1.1820
# Detected kernel version 4.15.0, which is below the recommended minimum of 5.5.0; this can cause the process to hang. It is recommended to upgrade the kernel to the minimum version or higher.
# [INFO|trainer.py:648] 2024-09-10 22:46:05,982 >> Using auto half precision backend
# [INFO|trainer.py:2134] 2024-09-10 22:46:06,777 >> ***** Running training *****
# [INFO|trainer.py:2135] 2024-09-10 22:46:06,777 >>   Num examples = 21,821
# [INFO|trainer.py:2136] 2024-09-10 22:46:06,777 >>   Num Epochs = 10
# [INFO|trainer.py:2137] 2024-09-10 22:46:06,777 >>   Instantaneous batch size per device = 8
# [INFO|trainer.py:2140] 2024-09-10 22:46:06,777 >>   Total train batch size (w. parallel, distributed & accumulation) = 32
# [INFO|trainer.py:2141] 2024-09-10 22:46:06,777 >>   Gradient Accumulation steps = 1
# [INFO|trainer.py:2142] 2024-09-10 22:46:06,777 >>   Total optimization steps = 6,820
# [INFO|trainer.py:2143] 2024-09-10 22:46:06,782 >>   Number of trainable parameters = 18,464,768
#   0%|                                                  | 0/6820 [00:00<?, ?it/s]/data2/anaconda3/envs/python3_10/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /data2/anaconda3/envs/python3_10/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /data2/anaconda3/envs/python3_10/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /data2/anaconda3/envs/python3_10/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /data2/anaconda3/envs/python3_10/lib/python3.10/site-packages/torch/utils/checkpoint.py:295: FutureWarning: `torch.cpu.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cpu', args...)` instead.
#   with torch.enable_grad(), device_autocast_ctx, torch.cpu.amp.autocast(**ctx.cpu_autocast_kwargs):  # type: ignore[attr-defined]
# /data2/anaconda3/envs/python3_10/lib/python3.10/site-packages/torch/utils/checkpoint.py:295: FutureWarning: `torch.cpu.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cpu', args...)` instead.
#   with torch.enable_grad(), device_autocast_ctx, torch.cpu.amp.autocast(**ctx.cpu_autocast_kwargs):  # type: ignore[attr-defined]
# /data2/anaconda3/envs/python3_10/lib/python3.10/site-packages/torch/utils/checkpoint.py:295: FutureWarning: `torch.cpu.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cpu', args...)` instead.
#   with torch.enable_grad(), device_autocast_ctx, torch.cpu.amp.autocast(**ctx.cpu_autocast_kwargs):  # type: ignore[attr-defined]
# /data2/anaconda3/envs/python3_10/lib/python3.10/site-packages/torch/utils/checkpoint.py:295: FutureWarning: `torch.cpu.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cpu', args...)` instead.
#   with torch.enable_grad(), device_autocast_ctx, torch.cpu.amp.autocast(**ctx.cpu_autocast_kwargs):  # type: ignore[attr-defined]
# {'loss': 1.2095, 'grad_norm': 1.7109360694885254, 'learning_rate': 2.9325513196480943e-06, 'epoch': 0.01}
# {'loss': 1.2552, 'grad_norm': 1.7627754211425781, 'learning_rate': 5.865102639296189e-06, 'epoch': 0.03}
# {'loss': 1.2071, 'grad_norm': 1.0131354331970215, 'learning_rate': 8.797653958944282e-06, 'epoch': 0.04}
# {'loss': 1.1754, 'grad_norm': 0.7777611613273621, 'learning_rate': 1.1730205278592377e-05, 'epoch': 0.06}
# {'loss': 1.0464, 'grad_norm': 0.6432637572288513, 'learning_rate': 1.4662756598240471e-05, 'epoch': 0.07}
# {'loss': 1.0228, 'grad_norm': 0.6786194443702698, 'learning_rate': 1.7595307917888564e-05, 'epoch': 0.09}
# {'loss': 0.9604, 'grad_norm': 0.6057329177856445, 'learning_rate': 2.052785923753666e-05, 'epoch': 0.1}
# {'loss': 1.0273, 'grad_norm': 0.6713504195213318, 'learning_rate': 2.3460410557184755e-05, 'epoch': 0.12}
# {'loss': 1.0033, 'grad_norm': 0.6976475715637207, 'learning_rate': 2.6392961876832843e-05, 'epoch': 0.13}
# {'loss': 0.9842, 'grad_norm': 0.7601083517074585, 'learning_rate': 2.9325513196480942e-05, 'epoch': 0.15}
#   1%|▌                                     | 100/6820 [02:04<2:20:16,  1.25s/it][INFO|trainer.py:3819] 2024-09-10 22:48:12,092 >>
# ***** Running Evaluation *****
# [INFO|trainer.py:
#   1%|▌                                     | 100/6820 [02:30<2:20:16,  1.25s/it]
# 100%|███████████████████████████████████████████| 76/76 [00:25<00:00,  3.06it/s]
# {'loss': 0.9971, 'grad_norm': 0.790885865688324, 'learning_rate': 3.2258064516129034e-05, 'epoch': 0.16}
# {'loss': 0.9616, 'grad_norm': 0.84432053565979, 'learning_rate': 3.519061583577713e-05, 'epoch': 0.18}
# {'loss': 0.9178, 'grad_norm': 0.8005008101463318, 'learning_rate': 3.8123167155425224e-05, 'epoch': 0.19}
# {'loss': 0.9722, 'grad_norm': 0.7508527636528015, 'learning_rate': 4.105571847507332e-05, 'epoch': 0.21}
# {'loss': 0.9504, 'grad_norm': 0.7976640462875366, 'learning_rate': 4.398826979472141e-05, 'epoch': 0.22}
# {'loss': 0.9425, 'grad_norm': 0.8183676600456238, 'learning_rate': 4.692082111436951e-05, 'epoch': 0.23}
# {'loss': 0.942, 'grad_norm': 0.8160320520401001, 'learning_rate': 4.98533724340176e-05, 'epoch': 0.25}
# {'loss': 0.9372, 'grad_norm': 0.8005610704421997, 'learning_rate': 5.2785923753665686e-05, 'epoch': 0.26}
# {'loss': 0.9694, 'grad_norm': 0.876216471195221, 'learning_rate': 5.571847507331378e-05, 'epoch': 0.28}
# {'loss': 0.9895, 'grad_norm': 0.8092273473739624, 'learning_rate': 5.8651026392961884e-05, 'epoch': 0.29}
#   3%|█                                     | 200/6820 [04:34<2:24:59,  1.31s/it][INFO|trainer.py:3819] 2024-09-10 22:50:41,524 >>
# ***** Running Evaluation *****
# [INFO|trainer.py:3821] 2024-09-10 22:50:41,524 >>   Num examples = 2425
# [INFO|trainer.py:3824] 2024-09-10 22:50:41,524 >>   Batch size = 8
#
#   0%|                                                    | 0/76 [00:00<?, ?it/s]
#   3%|█▏                                          | 2/76 [00:00<00:13,  5.63it/s]
#   4%|█▋                                          | 3/76 [00:00<00:18,  3.95it/s]
#   5%|██▎                                         | 4/76 [00:01<00:21,  3.38it/s]
#   7%|██▉                                         | 5/76 [00:01<00:21,  3.27it/s]
#   8%|███▍                                        | 6/76 [00:01<00:22,  3.06it/s]
#   9%|████                                        | 7/76 [00:02<00:22,  3.02it/s]
#  11%|████▋                                       | 8/76 [00:02<00:22,  2.99it/s]
#  12%|█████▏                                      | 9/76 [00:02<00:22,  2.94it/s]
#  13%|█████▋                                     | 10/76 [00:03<00:22,  2.95it/s]
#  14%|██████▏                                    | 11/76 [00:03<00:22,  2.90it/s]
#  16%|██████▊                                    | 12/76 [00:03<00:21,  2.94it/s]
#  17%|███████▎                                   | 13/76 [00:04<00:21,  2.95it/s]
#  18%|███████▉                                   | 14/76 [00:04<00:19,  3.16it/s]
#  20%|████████▍                                  | 15/76 [00:04<00:19,  3.08it/s]
#  21%|█████████                                  | 16/76 [00:05<00:19,  3.03it/s]
#  22%|█████████▌                                 | 17/76 [00:05<00:19,  3.06it/s]
#  24%|██████████▏                                | 18/76 [00:05<00:18,  3.22it/s]
#  25%|██████████▊                                | 19/76 [00:05<00:16,  3.39it/s]
# {'eval_loss': 0.9062034487724304, 'eval_runtime': 25.221, 'eval_samples_per_second': 96.15, 'eval_steps_per_second': 3.013, 'epoch': 0.44}
#   4%|█▋                                    | 300/6820 [07:29<2:23:06,  1.32s/it]
# 100%|███████████████████████████████████████████| 76/76 [00:24<00:00,  3.05it/s]
# {'loss': 0.8641, 'grad_norm': 0.8270260095596313, 'learning_rate': 9.090909090909092e-05, 'epoch': 0.45}
# {'loss': 0.8183, 'grad_norm': 0.8117917776107788, 'learning_rate': 9.384164222873902e-05, 'epoch': 0.47}
# {'loss': 0.8864, 'grad_norm': 0.8720026016235352, 'learning_rate': 9.677419354838711e-05, 'epoch': 0.48}
# {'loss': 0.9184, 'grad_norm': 0.8223180174827576, 'learning_rate': 9.97067448680352e-05, 'epoch': 0.5}
# {'loss': 0.8963, 'grad_norm': 0.8327614068984985, 'learning_rate': 9.999952388910049e-05, 'epoch': 0.51}
# {'loss': 0.9357, 'grad_norm': 0.7466409206390381, 'learning_rate': 9.999787808528638e-05, 'epoch': 0.53}
# {'loss': 0.9144, 'grad_norm': 0.7802152633666992, 'learning_rate': 9.999505674933167e-05, 'epoch': 0.54}
# {'loss': 0.9368, 'grad_norm': 0.7543938755989075, 'learning_rate': 9.999105994757059e-05, 'epoch': 0.56}
# {'loss': 0.9161, 'grad_norm': 0.8059861063957214, 'learning_rate': 9.99858877739745e-05, 'epoch': 0.57}
# {'loss': 0.8861, 'grad_norm': 0.803578794002533, 'learning_rate': 9.99795403501497e-05, 'epoch': 0.59}
#   6%|██▏                                   | 400/6820 [09:34<2:14:33,  1.26s/it][INFO|trainer.py:3819] 2024-09-10 22:55:41,733 >>
# ***** Running Evaluation *****
# [INFO|trainer.py:3821] 2024-09-10 22:55:41,734 >>   Num examples = 2425
# [INFO|trainer.py:3824] 2024-09-10 22:55:41,734 >>   Batch size = 8
#
#   0%|                                                    | 0/76 [00:00<?, ?it/s]
#   3%|█▏                                          | 2/76 [00:00<00:13,  5.63it/s]
#   4%|█▋                                          | 3/76 [00:00<00:18,  3.94it/s]
#   5%|██▎                                         | 4/76 [00:01<00:21,  3.37it/s]
#   7%|██▉                                         | 5/76 [00:01<00:21,  3.27it/s]
#   8%|███▍                                        | 6/76 [00:01<00:22,  3.06it/s]
#   9%|████                                        | 7/76 [00:02<00:22,  3.02it/s]
#  11%|████▋                                       | 8/76 [00:02<00:22,  2.99it/s]
#  12%|█████▏                                      | 9/76 [00:02<00:22,  2.94it/s]
#  13%|█████▋                                     | 10/76 [00:03<00:22,  2.95it/s]
#  14%|██████▏                                    | 11/76 [00:03<00:22,  2.90it/s]
#  16%|██████▊                                    | 12/76 [00:03<00:21,  2.94it/s]
#  17%|███████▎                                   | 13/76 [00:04<00:21,  2.95it/s]
#  18%|███████▉                                   | 14/76 [00:04<00:19,  3.16it/s]
#  20%|████████▍                                  | 15/76 [00:04<00:19,  3.07it/s]
# ...
#  43%|██████████████████▋                        | 33/76 [00:10<00:14,  2.98it/s]
#  45%|███████████████████▏                       | 34/76 [00:11<00:14,  2.92it/s]
#  96%|█████████████████████████████████████████▎ | 73/76 [00:23<00:01,  2.91it/s]
#  97%|█████████████████████████████████████████▊ | 74/76 [00:24<00:00,  3.01it/s]
#  99%|██████████████████████████████████████████▍| 75/76 [00:24<00:00,  3.00it/s]
#
# {'eval_loss': 1.1057268381118774, 'eval_runtime': 25.2125, 'eval_samples_per_second': 96.182, 'eval_steps_per_second': 3.014, 'epoch': 6.74}
#  67%|████████████████████████▉            | 4600/6820 [1:54:46<46:29,  1.26s/it]
# 100%|███████████████████████████████████████████| 76/76 [00:24<00:00,  3.05it/s]
# {'loss': 0.4051, 'grad_norm': 1.6628029346466064, 'learning_rate': 2.6064153592483675e-05, 'epoch': 6.76}
# {'loss': 0.4036, 'grad_norm': 1.5623234510421753, 'learning_rate': 2.585157719792106e-05, 'epoch': 6.77}
# {'loss': 0.3859, 'grad_norm': 1.5897780656814575, 'learning_rate': 2.5639568572396548e-05, 'epoch': 6.79}
# {'loss': 0.3988, 'grad_norm': 1.655057668685913, 'learning_rate': 2.5428132700580787e-05, 'epoch': 6.8}
# {'loss': 0.3967, 'grad_norm': 1.5126457214355469, 'learning_rate': 2.5217274553677972e-05, 'epoch': 6.82}
# {'loss': 0.3983, 'grad_norm': 1.689577579498291, 'learning_rate': 2.5006999089309108e-05, 'epoch': 6.83}
# {'loss': 0.4187, 'grad_norm': 1.5941047668457031, 'learning_rate': 2.47973112513953e-05, 'epoch': 6.85}
# {'loss': 0.4017, 'grad_norm': 1.7292183637619019, 'learning_rate': 2.458821597004167e-05, 'epoch': 6.86}
# {'loss': 0.404, 'grad_norm': 1.6324868202209473, 'learning_rate': 2.43797181614213e-05, 'epoch': 6.88}
# {'loss': 0.4213, 'grad_norm': 1.7789926528930664, 'learning_rate': 2.4171822727659738e-05, 'epoch': 6.89}
#  69%|█████████████████████████▍           | 4700/6820 [1:56:48<42:50,  1.21s/it][INFO|trainer.py:3819] 2024-09-11 00:42:55,306 >>
# ***** Running Evaluation *****
# [INFO|trainer.py:3821] 2024-09-11 00:42:55,306 >>   Num examples = 2425
# [INFO|trainer.py:3824] 2024-09-11 00:42:55,306 >>   Batch size = 8
#
#   0%|                                                    | 0/76 [00:00<?, ?it/s]
#   3%|█▏                                          | 2/76 [00:00<00:13,  5.63it/s]
#   4%|█▋                                          | 3/76 [00:00<00:18,  3.95it/s]
#   5%|██▎                                         | 4/76 [00:01<00:21,  3.38it/s]
#   7%|██▉                                         | 5/76 [00:01<00:21,  3.27it/s]
#   8%|███▍                                        | 6/76 [00:01<00:22,  3.06it/s]
#   9%|████                                        | 7/76 [00:02<00:22,  3.02it/s]
#  11%|████▋                                       | 8/76 [00:02<00:22,  2.99it/s]
#  12%|█████▏                                      | 9/76 [00:02<00:22,  2.94it/s]
#  13%|█████▋                                     | 10/76 [00:03<00:22,  2.95it/s]
#  14%|██████▏                                    | 11/76 [00:03<00:22,  2.90it/s]
#  16%|██████▊                                    | 12/76 [00:03<00:21,  2.94it/s]
#  17%|███████▎                                   | 13/76 [00:04<00:21,  2.95it/s]
#  43%|██████████████████▋                        | 33/76 [00:10<00:14,  2.98it/s]
#  45%|███████████████████▏                       | 34/76 [00:11<00:14,  2.92it/s]
#  46%|███████████████████▊                       | 35/76 [00:11<00:13,  3.01it/s]
#  47%|████████████████████▎                      | 36/76 [00:11<00:12,  3.16it/s]

# %% [markdown]
# ## 验证数据集上评估

# %%
# !ls -l /data2/anti_fraud/models/Qwen2-1___5B-Instruct_ft_0910
# Out:
# total 83896
# -rw-rw-r-- 1 xiaoguanghua xiaoguanghua      768 Sep 10 20:10 adapter_config.json
# -rw-rw-r-- 1 xiaoguanghua xiaoguanghua 73911112 Sep 10 20:10 adapter_model.safetensors
# -rw-rw-r-- 1 xiaoguanghua xiaoguanghua       80 Sep 10 20:10 added_tokens.json
# -rw-rw-r-- 1 xiaoguanghua xiaoguanghua      349 Sep 10 20:11 all_results.json
# drwxrwxr-x 2 xiaoguanghua xiaoguanghua     4096 Sep 10 17:45 checkpoint-1000
# drwxrwxr-x 2 xiaoguanghua xiaoguanghua     4096 Sep 10 17:57 checkpoint-1500
# drwxrwxr-x 2 xiaoguanghua xiaoguanghua     4096 Sep 10 18:10 checkpoint-2000
# drwxrwxr-x 2 xiaoguanghua xiaoguanghua     4096 Sep 10 18:22 checkpoint-2500
# drwxrwxr-x 2 xiaoguanghua xiaoguanghua     4096 Sep 10 18:35 checkpoint-3000
# drwxrwxr-x 2 xiaoguanghua xiaoguanghua     4096 Sep 10 18:47 checkpoint-3500
# drwxrwxr-x 2 xiaoguanghua xiaoguanghua     4096 Sep 10 19:00 checkpoint-4000
# drwxrwxr-x 2 xiaoguanghua xiaoguanghua     4096 Sep 10 19:12 checkpoint-4500
# drwxrwxr-x 2 xiaoguanghua xiaoguanghua     4096 Sep 10 17:32 checkpoint-500
# drwxrwxr-x 2 xiaoguanghua xiaoguanghua     4096 Sep 10 19:25 checkpoint-5000
# drwxrwxr-x 2 xiaoguanghua xiaoguanghua     4096 Sep 10 19:37 checkpoint-5500
# drwxrwxr-x 2 xiaoguanghua xiaoguanghua     4096 Sep 10 19:50 checkpoint-6000
# drwxrwxr-x 2 xiaoguanghua xiaoguanghua     4096 Sep 10 20:02 checkpoint-6500
# drwxrwxr-x 2 xiaoguanghua xiaoguanghua     4096 Sep 10 20:10 checkpoint-6820
# -rw-rw-r-- 1 xiaoguanghua xiaoguanghua      160 Sep 10 20:11 eval_results.json
# -rw-rw-r-- 1 xiaoguanghua xiaoguanghua  1671853 Sep 10 20:10 merges.txt
# -rw-rw-r-- 1 xiaoguanghua xiaoguanghua     5142 Sep 10 20:11 README.md
# drwxrwxr-x 3 xiaoguanghua xiaoguanghua     4096 Sep 10 17:20 runs
# -rw-rw-r-- 1 xiaoguanghua xiaoguanghua      367 Sep 10 20:10 special_tokens_map.json
# -rw-rw-r-- 1 xiaoguanghua xiaoguanghua     1533 Sep 10 20:10 tokenizer_config.json
# -rw-rw-r-- 1 xiaoguanghua xiaoguanghua  7028043 Sep 10 20:10 tokenizer.json
# -rw-rw-r-- 1 xiaoguanghua xiaoguanghua   184003 Sep 10 20:10 trainer_log.jsonl
# -rw-rw-r-- 1 xiaoguanghua xiaoguanghua   133619 Sep 10 20:10 trainer_state.json
# -rw-rw-r-- 1 xiaoguanghua xiaoguanghua     5368 Sep 10 20:10 training_args.bin
# -rw-rw-r-- 1 xiaoguanghua xiaoguanghua    36067 Sep 10 20:10 training_eval_loss.png
# -rw-rw-r-- 1 xiaoguanghua xiaoguanghua    48511 Sep 10 20:10 training_loss.png
# -rw-rw-r-- 1 xiaoguanghua xiaoguanghua      210 Sep 10 20:10 train_results.json
# -rw-rw-r-- 1 xiaoguanghua xiaoguanghua  2776833 Sep 10 20:10 vocab.json
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
# %run evaluate.py
testdata_path = '/data2/anti_fraud/dataset/eval0902.jsonl'
model_path = '/data2/anti_fraud/models/modelscope/hub/Qwen/Qwen2-1___5B-Instruct'
device = 'cuda:1'

# %%
# %%time
## eval_loss=0.0152
checkpoint_path_6500 = '/data2/anti_fraud/models/Qwen2-1___5B-Instruct_ft_0910/checkpoint-6500'
evaluate(model_path, checkpoint_path_6500, testdata_path, device, batch=True, debug=True)
# Out:
# progress: 100%|██████████| 3031/3031 [04:16<00:00, 11.83it/s]
# tn：1477, fp:52, fn:220, tp:1282
# precision: 0.9610194902548725, recall: 0.8535286284953395
# CPU times: user 4min 17s, sys: 25.9 s, total: 4min 42s
# Wall time: 4min 19s

# %%
# %%time
## eval_loss=0.0152
checkpoint_path_6500 = '/data2/anti_fraud/models/Qwen2-1___5B-Instruct_ft_0910-3/checkpoint-6500'
evaluate(model_path, checkpoint_path_6500, testdata_path, device, batch=True, debug=True)
# Out:
# progress:  61%|██████    | 1856/3031 [02:48<04:21,  4.49it/s]
# invalid json: {"input_text": "在对话中提到的某公司招聘，要求提供个人敏感信息（如身份证号码、银行卡号等），这是典型的诈骗行为。"} {"is_fraud": true}
# progress: 100%|██████████| 3031/3031 [04:28<00:00, 11.29it/s]
# tn：1451, fp:78, fn:150, tp:1352
# precision: 0.9454545454545454, recall: 0.9001331557922769
# CPU times: user 4min 26s, sys: 28.5 s, total: 4min 54s
# Wall time: 4min 31s

# %%
# !ls -l /data2/anti_fraud/models/Qwen2-1___5B-Instruct_ft_0910-3
# Out:
# total 83896
# -rw-rw-r-- 1 xiaoguanghua xiaoguanghua      768 Sep 11 01:36 adapter_config.json
# -rw-rw-r-- 1 xiaoguanghua xiaoguanghua 73911112 Sep 11 01:36 adapter_model.safetensors
# -rw-rw-r-- 1 xiaoguanghua xiaoguanghua       80 Sep 11 01:36 added_tokens.json
# -rw-rw-r-- 1 xiaoguanghua xiaoguanghua      349 Sep 11 01:36 all_results.json
# drwxrwxr-x 2 xiaoguanghua xiaoguanghua     4096 Sep 10 23:11 checkpoint-1000
# drwxrwxr-x 2 xiaoguanghua xiaoguanghua     4096 Sep 10 23:23 checkpoint-1500
# drwxrwxr-x 2 xiaoguanghua xiaoguanghua     4096 Sep 10 23:35 checkpoint-2000
# drwxrwxr-x 2 xiaoguanghua xiaoguanghua     4096 Sep 10 23:48 checkpoint-2500
# drwxrwxr-x 2 xiaoguanghua xiaoguanghua     4096 Sep 11 00:00 checkpoint-3000
# drwxrwxr-x 2 xiaoguanghua xiaoguanghua     4096 Sep 11 00:13 checkpoint-3500
# drwxrwxr-x 2 xiaoguanghua xiaoguanghua     4096 Sep 11 00:25 checkpoint-4000
# drwxrwxr-x 2 xiaoguanghua xiaoguanghua     4096 Sep 11 00:38 checkpoint-4500
# drwxrwxr-x 2 xiaoguanghua xiaoguanghua     4096 Sep 10 22:58 checkpoint-500
# drwxrwxr-x 2 xiaoguanghua xiaoguanghua     4096 Sep 11 00:50 checkpoint-5000
# drwxrwxr-x 2 xiaoguanghua xiaoguanghua     4096 Sep 11 01:03 checkpoint-5500
# drwxrwxr-x 2 xiaoguanghua xiaoguanghua     4096 Sep 11 01:15 checkpoint-6000
# drwxrwxr-x 2 xiaoguanghua xiaoguanghua     4096 Sep 11 01:28 checkpoint-6500
# drwxrwxr-x 2 xiaoguanghua xiaoguanghua     4096 Sep 11 01:36 checkpoint-6820
# -rw-rw-r-- 1 xiaoguanghua xiaoguanghua      160 Sep 11 01:36 eval_results.json
# -rw-rw-r-- 1 xiaoguanghua xiaoguanghua  1671853 Sep 11 01:36 merges.txt
# -rw-rw-r-- 1 xiaoguanghua xiaoguanghua     5147 Sep 11 01:36 README.md
# drwxrwxr-x 3 xiaoguanghua xiaoguanghua     4096 Sep 10 22:46 runs
# -rw-rw-r-- 1 xiaoguanghua xiaoguanghua      367 Sep 11 01:36 special_tokens_map.json
# -rw-rw-r-- 1 xiaoguanghua xiaoguanghua     1533 Sep 11 01:36 tokenizer_config.json
# -rw-rw-r-- 1 xiaoguanghua xiaoguanghua  7028043 Sep 11 01:36 tokenizer.json
# -rw-rw-r-- 1 xiaoguanghua xiaoguanghua   183796 Sep 11 01:36 trainer_log.jsonl
# -rw-rw-r-- 1 xiaoguanghua xiaoguanghua   133510 Sep 11 01:36 trainer_state.json
# -rw-rw-r-- 1 xiaoguanghua xiaoguanghua     5368 Sep 11 01:36 training_args.bin
# -rw-rw-r-- 1 xiaoguanghua xiaoguanghua    39614 Sep 11 01:36 training_eval_loss.png
# -rw-rw-r-- 1 xiaoguanghua xiaoguanghua    42483 Sep 11 01:36 training_loss.png
# -rw-rw-r-- 1 xiaoguanghua xiaoguanghua      210 Sep 11 01:36 train_results.json
# -rw-rw-r-- 1 xiaoguanghua xiaoguanghua  2776833 Sep 11 01:36 vocab.json

# %%
# %%time
# %run evaluate_v2.py
checkpoint_path = '/data2/anti_fraud/models/Qwen2-1___5B-Instruct_ft_0910-3/checkpoint-6500'
evaluate_v2(model_path, checkpoint_path, testdata_path, device, debug=True)
# Out:
# progress:  35%|███▍      | 1048/3031 [12:42<23:29,  1.41it/s]
# invalid json: {"is_fraud": true, "fraud_speaker": "王强", "reason": "王强通过引导李丽进行充值，并承诺稳赚不赔的收益，属于典型的网络投资诈骗手法。"}, {"is_fraud": true, "fraud_speaker": "张华", "reason": "张华冒充电商客服，要求覃军通过支付宝备用金功能将资金转到指定的银行卡账户上，这种操作方式具有明显的诈骗特征。"}
# progress:  37%|███▋      | 1128/3031 [13:42<23:41,  1.34it/s]
# invalid json: {"is_fraud": true, "fraud_speaker": "诈骗者", "reason": "在对话中，'诈骗者'引导'小梅'进行提现操作，并要求其提供银行账号信息。这是典型的网络博彩诈骗手段之一，通过获取受害者的银行信息进行进一步的欺诈行为。'}
# progress:  68%|██████▊   | 2072/3031 [25:11<15:33,  1.03it/s]
# invalid json: {"is_fraud": true, "fraud_speaker": "张伟", "reason": "张伟试图通过私下退款并额外返还20元的方式吸引李婷加入微信，并可能进一步获取她的个人信息。这种操作方式具有明显的诈骗特征，因为通常情况下，正规平台不会通过私下退款的方式处理问题，且张伟提到的信息可能是虚假的。"}, {"is_fraud": true, "fraud_speaker": "姜丽", "reason": "姜丽声称新出的一个套餐只需要支付20元并且可以每月获得120G的流量，但这种说法并不真实可信，可能是诱导用户充值或付款的骗局。"}, {"is_fraud": true, "fraud_speaker": "刘志强", "reason": "刘志强声称自己是某银行的客服，但银行一般不会通过这种方式通知客户账户问题，而且5万元转账境外的问题也不符合常理，可能是冒用银行名义进行诈骗。"}
# progress: 100%|██████████| 3031/3031 [36:49<00:00,  1.37it/s]
# is_fraud字段指标:
# tn：1421, fp:108, fn:93, tp:1409
# precision: 0.928806855636124, recall: 0.9380825565912118, accuracy: 0.9336852523919499
# fraud_speaker字段指标:
# accuracy: 0.90498185417354
# reason字段指标:
# precision: 0.44658668846108157, recall: 0.4553686294916234, f1-score: 0.4406380456120786
# CPU times: user 36min 42s, sys: 39.4 s, total: 37min 22s
# Wall time: 36min 56s
